# %% [markdown]
# <a href="https://colab.research.google.com/github/tanejanikhil3638/Multithreading/blob/main/Multithreading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import threading
import time
from tabulate import tabulate
import matplotlib.pyplot as plt

def matrix_multiply(A, B, result, index):
    result[index] = np.dot(A, B)

def run_with_threads(num_threads):
    start_time = time.time()
    threads = []
    for i, matrix in enumerate(matrices):
        thread = threading.Thread(target=matrix_multiply, args=(A, matrix, results, i))
        threads.append(thread)
        thread.start()
    for thread in threads:
        thread.join()
    end_time = time.time()
    return end_time - start_time

A = np.random.rand(1000, 1000) # Constant matrix

results = [None] * 100 # Results of matrix, multiplication

matrices = [np.random.rand(1000, 1000) for _ in range(100)] # random matrices

results_table = []
num_threads=list(range(1,11))
time_taken=[]
for num_t in num_threads:
    ttime= run_with_threads(num_t)
    time_taken.append(ttime)
    results_table.append(("T="+str(num_t), round(ttime,4)))

ans = list(zip(*results_table)) # for row wise

print(tabulate(ans,tablefmt="grid", showindex=["Threads", "Time taken (sec)"]))

plt.plot(num_threads, time_taken)
plt.xlabel('Number of Threads')
plt.ylabel('Time taken (sec)')
plt.title('No of threads vs Time taken')
plt.yticks([0.6 + i * 0.1 for i in range(8)])
plt.xticks(range(1,11))
plt.grid(True)
plt.show()
# Out:
# +------------------+--------+-------+--------+--------+--------+-------+--------+--------+--------+--------+
# | Threads          | T=1    | T=2   | T=3    | T=4    | T=5    | T=6   | T=7    | T=8    | T=9    | T=10   |
# +------------------+--------+-------+--------+--------+--------+-------+--------+--------+--------+--------+
# | Time taken (sec) | 8.2075 | 8.516 | 6.1725 | 7.5964 | 6.0756 | 8.328 | 6.0864 | 7.6939 | 6.0761 | 7.7243 |
# +------------------+--------+-------+--------+--------+--------+-------+--------+--------+--------+--------+

# %%
import numpy as np
import threading
import time
from tabulate import tabulate
import matplotlib.pyplot as plt

def matrix_multiply(A, B, result, index):
    result[index] = np.dot(A, B)

def run_with_threads(num_threads):
    start_time = time.time()
    threads = []
    for i, matrix in enumerate(matrices):
        thread = threading.Thread(target=matrix_multiply, args=(A, matrix, results, i))
        threads.append(thread)
        thread.start()
    for thread in threads:
        thread.join()
    end_time = time.time()
    return end_time - start_time

A = np.random.rand(1000, 1000) # Constant matrix

results = [None] * 100 # Results of matrix, multiplication

matrices = [np.random.rand(3000, 3000) for _ in range(100)] # random matrices

results_table = []
num_threads=list(range(1,11))
time_taken=[]
for num_t in num_threads:
    ttime= run_with_threads(num_t)
    time_taken.append(ttime)
    results_table.append(("T="+str(num_t), round(ttime,4)))

ans = list(zip(*results_table)) # for row wise

print(tabulate(ans,tablefmt="grid", showindex=["Threads", "Time taken (sec)"]))

plt.plot(num_threads, time_taken)
plt.xlabel('Number of Threads')
plt.ylabel('Time taken (sec)')
plt.title('No of threads vs Time taken')
plt.yticks([0.6 + i * 0.1 for i in range(8)])
plt.xticks(range(1,11))
plt.grid(True)
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# Exception in thread Thread-1385 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1386 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Exception in thread Thread-1388 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1389 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1390 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Thread-1387 (matrix_multiply)Exception in thread Thread-1391 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
# :
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1392 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1393 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# Exception in thread Thread-1395 (matrix_multiply):
# Traceback (most recent call last):
# Thread-1394 (matrix_multiply)Exception in thread Thread-1396 (matrix_multiply):
# :
# Traceback (most recent call last):
# Exception in thread Thread-1397 (matrix_multiply)  File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Thread-1398 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)  File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1399 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1400 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1401 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1402 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1403 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-1404 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1405 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1406 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-1407 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1408 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1409 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1410 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1411 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1412 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1413 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-1414 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
# Exception in thread     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Thread-1415 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Exception in thread ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Thread-1417 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Thread-1416 (matrix_multiply)Exception in thread Thread-1418 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1419 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1420 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1421 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1422 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1423 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1424 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1425 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-1426 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1427 (matrix_multiply):
# Exception in thread Thread-1428 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Exception in thread Thread-1430 (matrix_multiply)Thread-1429 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Exception in thread Thread-1431 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Thread-1432 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1433 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1434 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-1435 (matrix_multiply)    self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# :
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     Exception in thread Thread-1436 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# self.run()Exception in thread Thread-1437 (matrix_multiply):
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Traceback (most recent call last):
#
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     Exception in thread self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Thread-1438 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Thread-1439 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-1440 (matrix_multiply):
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1441 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1442 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1443 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Exception in thread Thread-1445 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1446 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
# Thread-1444 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1447 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1448 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-1449 (matrix_multiply)    self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1450 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1451 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-1452 (matrix_multiply)    self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1453 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Thread-1454 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1455 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1456 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1457 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     Exception in thread Exception in thread Thread-1459 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Thread-1458 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1460 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
# Exception in thread Thread-1461 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1462 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-1463 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     Exception in thread Thread-1464 (matrix_multiply):
# Traceback (most recent call last):
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
# self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
# Exception in thread     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Thread-1466 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Thread-1465 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-1467 (matrix_multiply):
# Traceback (most recent call last):
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# Exception in thread Thread-1468 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Thread-1469 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     Exception in thread self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Thread-1470 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1471 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-1472 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1474 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Thread-1475 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Thread-1473 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1476 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-1477 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Thread-1478 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1479 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1480 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1481 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1482 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1483 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1484 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1485 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1486 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1487 (matrix_multiply)Exception in thread Thread-1488 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread Thread-1489 (matrix_multiply):
# :
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1490 (matrix_multiply):
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1491 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1492 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1493 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread Exception in thread Thread-1495 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# ...
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1975 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1976 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1977 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1978 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1979 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1980 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Exception in thread Thread-1981 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Thread-1982 (matrix_multiply)    self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# :
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1983 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1984 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1985 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError    self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# : shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Exception in thread Thread-1987 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
# Thread-1986 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1988 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1989 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1990 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# Exception in thread Thread-1991 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1992 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1993 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1995 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Thread-1994 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1996 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1997 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-1998 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Exception in thread Thread-1999 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Thread-2000 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-2001 (matrix_multiply)Exception in thread Thread-2002 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# Exception in thread     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Thread-2003 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-2004 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-2005 (matrix_multiply)Exception in thread Thread-2006 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-2007 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-2008 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# Exception in thread Thread-2009 (matrix_multiply):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-0855b128e243>", line 8, in matrix_multiply
# ValueError: shapes (1000,1000) and (3000,3000) not aligned: 1000 (dim 1) != 3000 (dim 0)
# +------------------+--------+--------+--------+--------+--------+--------+--------+-------+--------+--------+
# | Threads          | T=1    | T=2    | T=3    | T=4    | T=5    | T=6    | T=7    | T=8   | T=9    | T=10   |
# +------------------+--------+--------+--------+--------+--------+--------+--------+-------+--------+--------+
# | Time taken (sec) | 0.6466 | 0.6688 | 0.6741 | 0.4938 | 0.5708 | 0.5438 | 0.6091 | 1.009 | 0.6145 | 0.5208 |
# +------------------+--------+--------+--------+--------+--------+--------+--------+-------+--------+--------+
